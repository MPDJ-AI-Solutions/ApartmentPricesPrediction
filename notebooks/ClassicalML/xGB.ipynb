# %% [markdown]
# # Imports
# Below are listed imports used in current notebook

# %%
import sys
sys.path.append('../../code')
from functions import *

import xgboost as xgb

# %% [markdown]
# # Model training and evaluation
# Data loading and preprocessing are presented in another notebook. Data for model are prepared with functions from functions.py

# %% [markdown]
# ## Price prediction

# %%
X_train, X_test, y_train, y_test = price_preprocessing()

# %%
xgb_model =  xgb.XGBRegressor()

xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

evaluate_model(y_test, y_pred)
# Out:
# MSE: 12071900160.280115
# MAE: 79990.14819767192
# R-squared: 0.8242530498036421

# %%
xgb_model =  xgb.XGBRegressor(
    n_estimators=100,
    max_depth=50,
    learning_rate=0.1,
    booster='gbtree'
)

xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

evaluate_model(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       1 xgb_model =  xgb.XGBRegressor(
#       2     n_estimators=500,
#       3     max_depth=50,
#       4     learning_rate=0.1,
#       5     booster='gbtree'
#       6 )
# ----> 8 xgb_model.fit(X_train, y_train)
#       9 y_pred = xgb_model.predict(X_test)
#      11 evaluate_model(y_test, y_pred)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\xgboost\sklearn.py:1090, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1079     obj = None
#    1081 (
#    1082     model,
#    1083     metric,
#    (...)
#    1088     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1089 )
# -> 1090 self._Booster = train(
#    1091     params,
#    1092     train_dmatrix,
#    1093     self.get_num_boosting_rounds(),
#    1094     evals=evals,
#    1095     early_stopping_rounds=early_stopping_rounds,
#    1096     evals_result=evals_result,
#    1097     obj=obj,
#    1098     custom_metric=metric,
#    1099     verbose_eval=verbose,
#    1100     xgb_model=model,
#    1101     callbacks=callbacks,
#    1102 )
#    1104 self._set_evaluation_result(evals_result)
#    1105 return self
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\xgboost\core.py:2051, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
#    2050     _check_call(
# -> 2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
xgb_model =  xgb.XGBRegressor(
    n_estimators=100,
    learning_rate=0.1,
    booster='gblinear'
)

xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

evaluate_model(y_test, y_pred)
# Out:
# MSE: 22873072736.206833
# MAE: 114171.2507174745
# R-squared: 0.5950038257670232
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 10
#       7 xgb_model.fit(X_train, y_train)
#       8 y_pred = xgb_model.predict(X_test)
# ---> 10 evaluate_model(y_test, y_pred)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\notebooks\ClassicalML\../../code\functions.py:38, in evaluate_model(true_data, predicted_data)
#      36 plt.title('Actual vs. Predicted Values')
#      37 plt.legend()
# ---> 38 plt.show()
#      40 errors = true_data - predicted_data
#      41 kde = gaussian_kde(errors)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\pyplot.py:607, in show(*args, **kwargs)
#     563 """
#     564 Display all open figures.
#     565
#    (...)
#     604 explicitly there.
#     605 """
#     606 _warn_if_gui_out_of_main_thread()
# --> 607 return _get_backend_mod().show(*args, **kwargs)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\IPython\core\formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\IPython\core\formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\backend_bases.py:2192, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2190 if bbox_inches:
#    2191     if bbox_inches == "tight":
# -> 2192         bbox_inches = self.figure.get_tightbbox(
#    2193             renderer, bbox_extra_artists=bbox_extra_artists)
#    2194         if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#    2195                 pad_inches == "layout"):
#    2196             h_pad = layout_engine.get()["h_pad"]
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\_api\deprecation.py:457, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     451 if len(args) > name_idx:
#     452     warn_deprecated(
#     453         since, message="Passing the %(name)s %(obj_type)s "
#     454         "positionally is deprecated since Matplotlib %(since)s; the "
#     455         "parameter will become keyword-only %(removal)s.",
#     456         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 457 return func(*args, **kwargs)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\figure.py:1783, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1779 if ax.get_visible():
#    1780     # some Axes don't take the bbox_extra_artists kwarg so we
#    1781     # need this conditional....
#    1782     try:
# -> 1783         bbox = ax.get_tightbbox(
#    1784             renderer, bbox_extra_artists=bbox_extra_artists)
#    1785     except TypeError:
#    1786         bbox = ax.get_tightbbox(renderer)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\_api\deprecation.py:457, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     451 if len(args) > name_idx:
#     452     warn_deprecated(
#     453         since, message="Passing the %(name)s %(obj_type)s "
#     454         "positionally is deprecated since Matplotlib %(since)s; the "
#     455         "parameter will become keyword-only %(removal)s.",
#     456         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 457 return func(*args, **kwargs)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\axes\_base.py:4471, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4468     bbox_artists = self.get_default_bbox_extra_artists()
#    4470 for a in bbox_artists:
# -> 4471     bbox = a.get_tightbbox(renderer)
#    4472     if (bbox is not None
#    4473             and 0 < bbox.width < np.inf
#    4474             and 0 < bbox.height < np.inf):
#    4475         bb.append(bbox)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\artist.py:365, in Artist.get_tightbbox(self, renderer)
#     349 def get_tightbbox(self, renderer=None):
#     350     """
#     351     Like `.Artist.get_window_extent`, but includes any clipping.
#     352
#    (...)
#     363         Returns None if clipping results in no intersection.
#     364     """
# --> 365     bbox = self.get_window_extent(renderer)
#     366     if self.get_clip_on():
#     367         clip_box = self.get_clip_box()
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\spines.py:158, in Spine.get_window_extent(self, renderer)
#     156     return bb
#     157 bboxes = [bb]
# --> 158 drawn_ticks = self.axis._update_ticks()
#     160 major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#     161 minor_tick = next(iter({*drawn_ticks} & {*self.axis.minorTicks}), None)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\axis.py:1306, in Axis._update_ticks(self)
#    1304     tick.label1.set_text(label)
#    1305     tick.label2.set_text(label)
# -> 1306 minor_locs = self.get_minorticklocs()
#    1307 minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1308 minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\axis.py:1537, in Axis.get_minorticklocs(self)
#    1535 minor_locs = np.asarray(self.minor.locator())
#    1536 if self.remove_overlapping_locs:
# -> 1537     major_locs = self.major.locator()
#    1538     transform = self._scale.get_transform()
#    1539     tr_minor_locs = transform.transform(minor_locs)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\ticker.py:2168, in MaxNLocator.__call__(self)
#    2166 def __call__(self):
#    2167     vmin, vmax = self.axis.get_view_interval()
# -> 2168     return self.tick_values(vmin, vmax)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\ticker.py:2176, in MaxNLocator.tick_values(self, vmin, vmax)
#    2173     vmin = -vmax
#    2174 vmin, vmax = mtransforms.nonsingular(
#    2175     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2176 locs = self._raw_ticks(vmin, vmax)
#    2178 prune = self._prune
#    2179 if prune == 'lower':
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\ticker.py:2109, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2107 if self._nbins == 'auto':
#    2108     if self.axis is not None:
# -> 2109         nbins = np.clip(self.axis.get_tick_space(),
#    2110                         max(1, self._min_n_ticks - 1), 9)
#    2111     else:
#    2112         nbins = 9
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\axis.py:2792, in YAxis.get_tick_space(self)
#    2791 def get_tick_space(self):
# -> 2792     ends = mtransforms.Bbox.unit().transformed(
#    2793         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2794     length = ends.height * 72
#    2795     # Having a spacing of at least 2 just looks good.
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\transforms.py:468, in BboxBase.transformed(self, transform)
#     464 """
#     465 Construct a `Bbox` by statically transforming this one by *transform*.
#     466 """
#     467 pts = self.get_points()
# --> 468 ll, ul, lr = transform.transform(np.array(
#     469     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     470 return Bbox([ll, [lr[0], ul[1]]])
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\transforms.py:1505, in Transform.transform(self, values)
#    1502 values = values.reshape((-1, self.input_dims))
#    1504 # Transform the values
# -> 1505 res = self.transform_affine(self.transform_non_affine(values))
#    1507 # Convert the result back to the shape of the input values.
#    1508 if ndim == 0:
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\_api\deprecation.py:300, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     295     warn_deprecated(
#     296         since, message=f"The {old!r} parameter of {func.__name__}() "
#     297         f"has been renamed {new!r} since Matplotlib {since}; support "
#     298         f"for the old name will be dropped %(removal)s.")
#     299     kwargs[new] = kwargs.pop(old)
# --> 300 return func(*args, **kwargs)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\transforms.py:2419, in CompositeGenericTransform.transform_affine(self, values)
#    2416 @_api.rename_parameter("3.8", "points", "values")
#    2417 def transform_affine(self, values):
#    2418     # docstring inherited
# -> 2419     return self.get_affine().transform(values)
#
# File d:\Projects\POLSL\BIAI\ApartmentPricesPrediction\venv\Lib\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# KeyboardInterrupt:

# %%
xgb_model =  xgb.XGBRegressor(
    n_estimators=100,
    max_depth=50,
    learning_rate=0.1,
    booster='dart'
)

xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

evaluate_model(y_test, y_pred)

# %%
xgb_model =  xgb.XGBRegressor(
    n_estimators=50, 
    max_depth=15, 
    learning_rate=0.1,
    random_state=42
)

xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

evaluate_model(y_test, y_pred)

# %% [markdown]
# # Rent prediction

# %%
X_train, X_test, y_train, y_test = rent_preprocessing()

# %%
xgb_model =  xgb.XGBRegressor()

xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

evaluate_model(y_test, y_pred)

# %%
xgb_model =  xgb.XGBRegressor(
    n_estimators=100,
    max_depth=50,
    learning_rate=0.1,
    booster='gbtree'
)

xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

evaluate_model(y_test, y_pred)

# %%
xgb_model =  xgb.XGBRegressor(
    n_estimators=100,
    learning_rate=0.1,
    booster='gblinear'
)

xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

evaluate_model(y_test, y_pred)

# %%
xgb_model =  xgb.XGBRegressor(
    n_estimators=100,
    max_depth=50,
    learning_rate=0.1,
    booster='dart'
)

xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

evaluate_model(y_test, y_pred)

# %%
xgb_model =  xgb.XGBRegressor(
    n_estimators=50, 
    max_depth=15, 
    learning_rate=0.1,
    random_state=42
)

xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

evaluate_model(y_test, y_pred)
